# %% [markdown]
# # Analysis of Variance of Read Counts
# To support evaluation of classifiers, we need to know the variance (standard deviations) of read counts that are normalized in several ways: by library size, by gene size, and w.r.t. time 0. Two variances are of interest. The first is the variability of replications for the same gene and time. The second is the variability of mean values of replicas for a gene.

# %%
import init
from common import constants as cn
from common.data_provider import DataProvider
from common_python.plots import util_plots

import os
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %matplotlib inline

# %% [markdown]
# ## Data

# %%
provider = DataProvider()
provider.do()

# %%
# The data used in this analysis is a list of dataframe "matrix" that are the log2 values of the
# libary and gene adjusted readcounts divided by time 0.
# Each data frame has columns of genes and rows of time.
dfs = provider.dfs_adjusted_read_count_wrt0
matrices = [df.T[1:] for df in dfs]
for matrix in matrices:
    matrix = matrix.applymap(lambda v: 0 if v == 0 else np.log(v))

# %%
matrices[0].head()
# Out:
#      Rv0001    Rv0005    Rv0006    Rv0009   Rv0010c   Rv0011c    Rv0013  \
# 1  1.072119  1.637825  1.628194  1.959713  1.378715  0.996944  1.666453
# 2  1.301797  1.730923  1.519583  2.390467  1.160466  1.152987  1.498363
# 3  1.255190  2.040822  1.936701  1.762375  1.171577  1.538041  1.400058
# 4  1.353351  1.984227  1.928850  2.045719  1.136251  1.200222  1.161079
# 5  1.274508  1.989241  1.580781  2.008867  1.267012  1.412982  1.467291
#
#     Rv0014c   Rv0016c   Rv0020c  ...    Rvnt36    Rvnt37    Rvnt38    Rvnt39  \
# 1  1.638025  1.375098  1.475387  ...  0.496280  0.792937  0.427036  0.455354
# 2  1.626492  1.405057  1.659761  ...  0.973684  0.467172  0.407508  0.562189
# 3  1.490660  1.295392  1.548468  ...  0.337012  0.369778  0.547845  0.328393
# 4  1.642649  1.405477  1.562457  ...  0.545159  0.380754  0.223361  0.322582
# 5  1.684560  1.281612  1.857274  ...  0.409178  0.202661  0.143987  0.260133
#
#      Rvnt40    Rvnt41    Rvnt42    Rvnt43    Rvnt44    Rvnt45
# 1  0.848166  1.448165  0.437719  0.745297  0.655512  0.857393
# 2  0.713544  2.241541  0.516432  0.714582  0.992488  0.689073
# 3  0.899654  0.994830  0.529903  0.118391  1.138566  0.283450
# 4  0.586064  1.232037  0.174814  0.055071  0.454141  0.120963
# 5  0.714756  1.393947  0.137482  0.255278  0.573114  0.167321
#
# [5 rows x 2582 columns]

# %%
len(matrices[0].columns)
# Out:
# 2582

# %% [markdown]
# ## Variance Across times

# %%
mean_mat = np.mean(matrices)
std_mat = np.std(matrices)
# Out:
# ------------------------------------------------------------------------
# ValueError                             Traceback (most recent call last)
# <ipython-input-29-1b749eb4b143> in <module>
# ----> 1 mean_mat = np.mean(matrices)
#       2 std_mat = np.std(matrices)
#
# <__array_function__ internals> in mean(*args, **kwargs)
#
# ~/miniconda3/envs/xstate/lib/python3.8/site-packages/numpy/core/fromnumeric.py in mean(a, axis, dtype, out, keepdims)
#    3254             return mean(axis=axis, dtype=dtype, out=out, **kwargs)
#    3255
# -> 3256     return _methods._mean(a, axis=axis, dtype=dtype,
#    3257                           out=out, **kwargs)
#    3258
#
# ~/miniconda3/envs/xstate/lib/python3.8/site-packages/numpy/core/_methods.py in _mean(a, axis, dtype, out, keepdims)
#     133
#     134 def _mean(a, axis=None, dtype=None, out=None, keepdims=False):
# --> 135     arr = asanyarray(a)
#     136
#     137     is_float16_result = False
#
# ~/miniconda3/envs/xstate/lib/python3.8/site-packages/numpy/core/_asarray.py in asanyarray(a, dtype, order)
#     136
#     137     """
# --> 138     return array(a, dtype, copy=False, order=order, subok=True)
#     139
#     140
#
# ValueError: cannot copy sequence with size 25 to array axis with dimension 2582

# %%
avg_mat.head()
# Out:
#      Rv0001    Rv0005    Rv0006    Rv0009   Rv0010c   Rv0011c    Rv0013  \
# 1  1.016997  1.349613  1.348860  1.713399  1.289110  1.010606  1.461666
# 2  1.318838  1.657061  1.472357  2.103642  1.250123  1.265521  1.334447
# 3  1.194420  1.617192  1.763478  1.632163  1.171438  1.319795  1.277632
# 4  1.155473  1.635137  1.709586  1.780096  1.146901  1.095613  1.205745
# 5  1.139123  1.607045  1.417559  1.534280  1.093589  1.140771  1.106032
#
#     Rv0014c   Rv0016c   Rv0020c  ...    Rvnt36    Rvnt37    Rvnt38    Rvnt39  \
# 1  1.269363  1.301147  1.310925  ...  1.184997  1.573115  3.003892  1.221309
# 2  1.361027  1.344718  1.510973  ...  1.086868  1.075029  1.854107  0.920354
# 3  1.318328  1.331028  1.451523  ...  0.821168  1.492505  1.860031  0.499389
# 4  1.406766  1.407687  1.592445  ...  0.628807  1.138256  1.674123  0.636425
# 5  1.234154  1.212447  1.531050  ...  1.140393  1.791139  2.723280  1.178717
#
#      Rvnt40    Rvnt41    Rvnt42    Rvnt43    Rvnt44    Rvnt45
# 1  0.893812  0.829988  1.302780  1.066189  1.099224  2.613137
# 2  0.832404  1.425029  0.848703  0.607561  1.185813  1.050341
# 3  0.781539  1.060353  1.007913  0.315309  1.315067  0.834655
# 4  0.633919  1.171631  0.765200  0.296520  0.956015  0.718857
# 5  0.938784  1.247793  1.132774  1.225949  1.090984  1.072698
#
# [5 rows x 2582 columns]
